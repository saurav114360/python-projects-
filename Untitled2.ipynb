# %%
# load the data set
import pandas as pd

# %%
# read the csv file
df = pd.read_csv(r"C:\Users\Gaurav\Downloads\insurance_missing.csv")
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900       0.0    yes  southwest  16884.92400
# 1   18    male  33.770       1.0     no  southeast   1725.55230
# 2   28    male  33.000       3.0     no  southeast   4449.46200
# 3   33    male  22.705       0.0     no  northwest  21984.47061
# 4   32    male  28.880       0.0     no  northwest   3866.85520

# %% [markdown]
# ### data analyse and preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1334 non-null   object
#  2   bmi       1336 non-null   float64
#  3   children  1337 non-null   float64
#  4   smoker    1337 non-null   object
#  5   region    1336 non-null   object
#  6   charges   1335 non-null   float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 73.3+ KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         4
# bmi         2
# children    1
# smoker      1
# region      2
# charges     3
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df['age'].value_counts()
# Out:
# age
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: count, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# male      673
# female    661
# Name: count, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# sex
# male      673
# female    661
# Name: count, dtype: int64

# %%
df['bmi'].value_counts()
# Out:
# bmi
# 32.300    13
# 28.310     9
# 30.800     8
# 30.875     8
# 34.100     8
#           ..
# 46.200     1
# 23.800     1
# 44.770     1
# 32.120     1
# 30.970     1
# Name: count, Length: 547, dtype: int64

# %%
df['children'].value_counts()
# Out:
# children
# 0.0    574
# 1.0    324
# 2.0    239
# 3.0    157
# 4.0     25
# 5.0     18
# Name: count, dtype: int64

# %%
df['smoker'].value_counts()
# Out:
# smoker
# no     1064
# yes     273
# Name: count, dtype: int64

# %%
df['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northeast    324
# northwest    323
# Name: count, dtype: int64

# %%
df['charges'].value_counts()
# Out:
# charges
# 1639.56310     2
# 16884.92400    1
# 7243.81360     1
# 1634.57340     1
# 2221.56445     1
#               ..
# 11454.02150    1
# 12730.99960    1
# 7345.08400     1
# 26109.32905    1
# 29141.36030    1
# Name: count, Length: 1334, dtype: int64

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1336.000000  1337.000000   1335.000000
# mean     39.207025    30.667990     1.094241  13285.444135
# std      14.049960     6.101387     1.205689  12116.988644
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.291250     0.000000   4746.698450
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16717.010750
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df['age'].mean()
# Out:
# 39.20702541106129

# %%
df['age'].median()
# Out:
# 39.0

# %%
df['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %%
df['region'].mode()
# Out:
# 0    southeast
# Name: region, dtype: object

# %%
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(df['age'])
plt.title('Boxplot of age')
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.boxplot(df['bmi'])
plt.title('Boxplot of bmi')
plt.show()

# %%
sns.boxplot(df['charges'])
plt.title('Boxplot of charges')
plt.show()

# %%
df['bmi'].median()
# Out:
# 30.4

# %%
sns.boxplot(df['children'])
plt.title('Boxplot of children')
plt.show()

# %%
df['bmi'] = df['bmi'].fillna(df['bmi'].median())

# %%
df.isnull().sum()
# Out:
# age         0
# sex         4
# bmi         0
# children    1
# smoker      1
# region      2
# charges     3
# dtype: int64

# %%
df['charges'] = df['charges'].fillna(df['charges'].median())

# %%
df.isnull().sum()
# Out:
# age         0
# sex         4
# bmi         0
# children    1
# smoker      1
# region      2
# charges     0
# dtype: int64

# %%
sns.countplot(x = 'region', data = df,palette='rainbow')
plt.show()

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900       0.0    yes  southwest  16884.92400
# 1   18    male  33.770       1.0     no  southeast   1725.55230
# 2   28    male  33.000       3.0     no  southeast   4449.46200
# 3   33    male  22.705       0.0     no  northwest  21984.47061
# 4   32    male  28.880       0.0     no  northwest   3866.85520

# %%
sns.countplot(x = 'smoker', data = df,palette='rainbow')
plt.show()

# %%
df.isnull().sum()
# Out:
# age         0
# sex         4
# bmi         0
# children    1
# smoker      1
# region      2
# charges     0
# dtype: int64

# %%
df['region'] = df['region'].fillna(df['region'].median())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df['region'] = df['region'].fillna(df['region'].median())
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:6559, in Series.median(self, axis, skipna, numeric_only, **kwargs)
#    6551 @doc(make_doc("median", ndim=1))
#    6552 def median(
#    6553     self,
#    (...)
#    6557     **kwargs,
#    6558 ):
# -> 6559     return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:12431, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12424 def median(
#   12425     self,
#   12426     axis: Axis | None = 0,
#    (...)
#   12429     **kwargs,
#   12430 ) -> Series | float:
# > 12431     return self._stat_function(
#   12432         "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         4
# bmi         0
# children    1
# smoker      1
# region      2
# charges     0
# dtype: int64

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Gaurav\Downloads\Zomato Project_data.csv")
df.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['name'].value_counts()
# Out:
# name
# San Churro Cafe               2
# CAFE NOVA                     2
# Onesta                        2
# Jalsa                         1
# Kotian Karavali Restaurant    1
#                              ..
# Kitchen Garden                1
# Hotboxit                      1
# Domino's Pizza                1
# McDonald's                    1
# Vijayalakshmi                 1
# Name: count, Length: 145, dtype: int64

# %%
df['online_order'].value_counts()
# Out:
# online_order
# No     90
# Yes    58
# Name: count, dtype: int64

# %%
df['book_table'].value_counts()
# Out:
# book_table
# No     140
# Yes      8
# Name: count, dtype: int64

# %%
df['rate'].value_counts()
# Out:
# rate
# 3.8/5     19
# 3.7/5     15
# 3.3/5     14
# 3.4/5     12
# 4.1/5     11
# 3.6/5     11
# 4.0/5     10
# 3.9/5     10
# 4.2/5      8
# 3.1/5      7
# 2.9/5      7
# 3.2/5      7
# 3.5/5      6
# 3.0/5      2
# 4.6/5      2
# 2.8/5      2
# 4.4/5      2
# 4.3/5      1
# 2.6/5      1
# 3.8 /5     1
# Name: count, dtype: int64

# %%
df['votes'].value_counts()
# Out:
# votes
# 0       33
# 28       4
# 8        4
# 62       3
# 17       3
#         ..
# 1647     1
# 91       1
# 230      1
# 415      1
# 47       1
# Name: count, Length: 90, dtype: int64

# %%
from matplotlib import pyplot as plt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.boxplot(df['name'])
plt.title('Boxplot of name')
plt.show()

# %%
sns.boxplot(df['rate'])
plt.title('Boxplot of rate')
plt.show()

# %%
sns.boxplot(df['votes'])
plt.title('Boxplot of votes')
plt.show()

# %%
df['name'] = df['name'].fillna(df['name'].mode())

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
df['online_order'] = df['online_order'].fillna(df['online_order'].mode())

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
df['book_table'] = df['book_table'].fillna(df['book_table'].mode())

# %%
df.isnull().sum()
# Out:
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# approx_cost(for two people)    0
# listed_in(type)                0
# dtype: int64

# %%
sns.countplot(df['rate'])
plt.show()

# %%
df['online_order'].value_counts()
# Out:
# online_order
# No     90
# Yes    58
# Name: count, dtype: int64

# %%
df['book_table'].value_counts()
# Out:
# book_table
# No     140
# Yes      8
# Name: count, dtype: int64

# %%
df['approx_cost(for two people)'].mean()
# Out:
# 418.2432432432432

# %%
sns.boxplot(df['approx_cost(for two people)'])
plt.show()

# %%
a=df.groupby('rate')['votes'].mean()
a
# Out:
# rate
# 2.6/5      283.000000
# 2.8/5      298.500000
# 2.9/5       15.571429
# 3.0/5       80.000000
# 3.1/5       46.142857
# 3.2/5       16.428571
# 3.3/5        8.642857
# 3.4/5        1.333333
# 3.5/5       21.166667
# 3.6/5       84.272727
# 3.7/5       91.400000
# 3.8 /5      45.000000
# 3.8/5      183.368421
# 3.9/5      219.100000
# 4.0/5      509.800000
# 4.1/5      532.636364
# 4.2/5      453.000000
# 4.3/5      345.000000
# 4.4/5     4642.500000
# 4.6/5     2556.000000
# Name: votes, dtype: float64

# %%
b=df.groupby('online_order')['votes'].mean()
b
# Out:
# online_order
# No      75.222222
# Yes    559.000000
# Name: votes, dtype: float64

# %%
b=df.groupby('listed_in(type)')['votes'].median()
b
# Out:
# listed_in(type)
# Buffet    286.0
# Cafes     133.0
# Dining     28.0
# other     384.5
# Name: votes, dtype: float64

# %%
df.groupby('book_table')['approx_cost(for two people)'].mean()
# Out:
# book_table
# No     402.50
# Yes    693.75
# Name: approx_cost(for two people), dtype: float64
