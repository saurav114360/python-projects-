# %%
import pandas as pd 
import numpy as np

# %%
###

# %%
# create a dataframe having marks values

df1 = pd.DataFrame([4,6,8,5,2,5])

# %%
df1
# Out:
#    0
# 0  4
# 1  6
# 2  8
# 3  5
# 4  2
# 5  5

# %%
df2 = pd.DataFrame([4,6,8,5,2,5,25])

# %% [markdown]
# ### mean

# %%
df1.mean()
# Out:
# 0    5.0
# dtype: float64

# %% [markdown]
# ### handing outliers

# %%
x = df2.mean()

# %%
x
# Out:
# 0    7.857143
# dtype: float64

# %%
x.round(1)
# Out:
# 0    7.9
# dtype: float64

# %%
df2.median() # i can replace the outliers and missing value also
# Out:
# 0    5.0
# dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
df1.boxplot()
plt.show()

# %%
df2.boxplot()
plt.show()

# %%
df2.describe()
# Out:
#                0
# count   7.000000
# mean    7.857143
# std     7.776644
# min     2.000000
# 25%     4.500000
# 50%     5.000000
# 75%     7.000000
# max    25.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       7 non-null      int64
# dtypes: int64(1)
# memory usage: 188.0 bytes

# %% [markdown]
# ### mode

# %%
import pandas as pd
df3 = pd.DataFrame([2,6,7,8,9,2])

# %%
df3.mode()
# Out:
#    0
# 0  2

# %%
df4 = pd.DataFrame([2,6,7,2,8,9,8])
df4.mode()
# Out:
#    0
# 0  2
# 1  8

# %%
df5 = pd.DataFrame([2,6,7,1,8,9,20])
df5.mode()
# Out:
#     0
# 0   1
# 1   2
# 2   6
# 3   7
# 4   8
# 5   9
# 6  20
